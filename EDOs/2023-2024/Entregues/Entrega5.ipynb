# %% [markdown]
# <a href="https://colab.research.google.com/github/joseflix/DocenciaUAB/blob/master/EDOs/2023-2024/Entregues/Entrega5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Entrega 5**
#
# <hr>
#
# **Noms:**
#
# **NIUs:**
#
# **mails (gmail):**
#
# <hr>
#
# **Instruccions**
#
# *   Primer copieu aquest notebook al vostre drive (Archivo>Guardar una copia en Drive).
# *   Ompliu noms, NIUs i correus electrònics (gmail, si voleu rebre comentaris/feedback sobre la entrega) a l'encapçalament d'aquest Notebook.
# *   Canvia el nom del Notebook a "Entrega5.ipynb".
# *   Aneu gravant/guardant el Notebook de forma regular.
# *   Quan volgueu entregar, descarrega aquest quadern en format .ipynb i l'heu de pujar al següent *drop folder*: [Link](https://cern.ch/uabedopr). Assegureu-vos que el fitxer té el nom correcte.
# <hr>
#
# En aquesta entrega es tracta de dibuixar un camp de pendents de *les solucions ortogonals" d'una EDO, i dibuixar a damunt algunes corbes *ortogonals* a les solucions de la EDO.
#
# Per exemple, la equació $y' = x - y$ té sol·lucions del tipus $y = Ce^{-x} +x -1$. El camp de pendents i les sol·lucions per a alguns valors de C en l'interval [-10,10] és:
#
# ![test.png](data:image/png;base64,...)

# %% [markdown]
# L'equació original que fareu servir per a dibuixar el camp de pendents de les trajectòries ortogonals i les solucions ortogonals és:
#
# $$
# (2x+3y)dx + (3x+2y)dy=0
# $$
#
# Que és solucionable i té com a sol·lucions implícites:
#
# $$
# x^2 +3xy + y^2 = C
# $$
#
# Heu de trobar les solucions ortogonals a partir d'aqui...
#
# 1.   Implementa i dibuixa un camp de pendents **ortogonals** en una regió que vagi de -3 a 3, tant en $x$ com en $y$, d'acord amb aquesta EDO. **[4 punts]**
# 2.   Dibuixa algunes solucions de la EDO per verificar que el camp de pendents **ortogonals dibuixat** és correcte. Pots afegir alguna sol·lució ortogonal a la gràfica**[4 punts]**
# 3.   Existeix alguna llibrería de Python que et permeti dibuixar camp de pendents ortogonals de EDOs? Si és així, aplica aquest mètode per replicar el que has fet en les seccions anteriors. **[2 punts]**

# %%
# Secció 1

# %%
# Secció 2

# %%
# Secció 3
